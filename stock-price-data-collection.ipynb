# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
# !pip install vnstock3
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot
from vnstock3 import Vnstock
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Requirement already satisfied: vnstock3 in /opt/conda/lib/python3.10/site-packages (0.3.0.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from vnstock3) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from vnstock3) (4.12.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from vnstock3) (2.2.2)
# Requirement already satisfied: vnai>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from vnstock3) (0.1.3)
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.10/site-packages (from vnstock3) (3.1.5)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (from vnstock3) (2.5.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from vnstock3) (5.9.3)
# Requirement already satisfied: fake-useragent in /opt/conda/lib/python3.10/site-packages (from vnstock3) (1.5.1)
# Requirement already satisfied: vnstock-ezchart in /opt/conda/lib/python3.10/site-packages (from vnstock3) (0.0.2)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.10/site-packages (from vnai>=0.1.3->vnstock3) (41.0.7)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->vnstock3) (2.5)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.10/site-packages (from openpyxl->vnstock3) (1.1.0)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->vnstock3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->vnstock3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->vnstock3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->vnstock3) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic->vnstock3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic->vnstock3) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic->vnstock3) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->vnstock3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->vnstock3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->vnstock3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->vnstock3) (2024.7.4)
# Requirement already satisfied: squarify in /opt/conda/lib/python3.10/site-packages (from vnstock-ezchart->vnstock3) (0.4.3)
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.10/site-packages (from vnstock-ezchart->vnstock3) (1.9.3)
# Requirement already satisfied: vnstock in /opt/conda/lib/python3.10/site-packages (from vnstock-ezchart->vnstock3) (0.2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->vnstock3) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography->vnai>=0.1.3->vnstock3) (1.16.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud->vnstock-ezchart->vnstock3) (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud->vnstock-ezchart->vnstock3) (3.7.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography->vnai>=0.1.3->vnstock3) (2.21)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud->vnstock-ezchart->vnstock3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud->vnstock-ezchart->vnstock3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud->vnstock-ezchart->vnstock3) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud->vnstock-ezchart->vnstock3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud->vnstock-ezchart->vnstock3) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud->vnstock-ezchart->vnstock3) (3.1.1)

# %% [markdown]
# Dữ liệu được truy xuất từ Vnstock - gói phần mềm Python phân tích thị trường chứng khoán Việt Nam.
# (thinh-vu @ Github, Copyright (c) 2022-2024).

# %% [markdown]
# # Collecting data

# %%
stock = Vnstock().stock(symbol='MCH', source='VCI')
# Out:
# 2024-08-03 02:19:55,516 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS

# %%
stock1 = Vnstock().stock(source='VCI')
# Out:
# 2024-08-03 02:19:55,540 - vnstock3.common.vnstock - INFO - Mã chứng khoán không được chỉ định, chương trình mặc định sử dụng VN30F1M
# 2024-08-03 02:19:55,550 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS

# %%
df_cat = stock1.listing.symbols_by_industries()
df_cat.head()
# Out:
#   symbol                                         organ_name  \
# 0    CCC                       Công ty Cổ Phần Xây Dựng CDC
# 1    HIO                       Công ty Cổ Phần Helio Energy
# 2    TSA       Công ty Cổ Phần Đầu Tư Và Xây Lắp Trường Sơn
# 3    CST                 Công ty Cổ phần Than Cao Sơn - TKV
# 4    SGI  Công ty Cổ phần Đầu tư phát triển Sài Gòn 3 Group
#
#                                        en_organ_name  \
# 0               CDC Construction Joint Stock Company
# 1                   Helio Energy Joint Stock Company
# 2  Truong Son Investment And Construction Joint S...
# 3                   Cao Son Coal Joint Stock Company
# 4  Sai Gon 3 Group Investment Development Joint S...
#
#                    icb_name3              en_icb_name3  \
# 0       Xây dựng và Vật liệu  Construction & Materials
# 1  Sản xuất & Phân phối Điện               Electricity
# 2       Xây dựng và Vật liệu  Construction & Materials
# 3                Khai khoáng                    Mining
# 4               Hàng cá nhân            Personal Goods
#
#                        icb_name2                en_icb_name2  \
# 0           Xây dựng và Vật liệu    Construction & Materials
# 1  Điện, nước & xăng dầu khí đốt                   Utilities
# 2           Xây dựng và Vật liệu    Construction & Materials
# 3              Tài nguyên Cơ bản             Basic Resources
# 4        Hàng cá nhân & Gia dụng  Personal & Household Goods
#
#                    icb_name4              en_icb_name4 com_type_code  \
# 0                   Xây dựng        Heavy Construction            CT
# 1  Sản xuất & Phân phối Điện  Conventional Electricity            CT
# 2                   Xây dựng        Heavy Construction            CT
# 3             Khai thác Than                      Coal            CT
# 4               Hàng May mặc    Clothing & Accessories            CT
#
#   icb_code1 icb_code2 icb_code3 icb_code4
# 0      2000      2300      2350      2357
# 1      7000      7500      7530      7535
# 2      2000      2300      2350      2357
# 3      1000      1700      1770      1771
# 4      3000      3700      3760      3763

# %%
df_cat.shape
# Out:
# (1588, 14)

# %%
df_fin = stock.finance.ratio(period='quarter')
df_fin.head()
# Out:
#     Meta                         Chỉ tiêu định giá                           \
#   ticker yearReport lengthReport               P/B Market Capital (Bn. VND)
# 0    MCH       2024            2          4.955222          144839582045940
# 1    MCH       2024            1          5.077884          139499893790988
# 2    MCH       2023            4          3.725532           96222014662536
# 3    MCH       2023            3          2.755326           64759322217107
# 4    MCH       2023            2          2.197743           54762782121166
#
#                                                                     \
#   Outstanding Share (Mil. Shares)        P/E       P/S P/Cash Flow
# 0                       717507156  19.332802  4.877609   22.156469
# 1                       717507156  18.951058  4.846342   21.443997
# 2                       717507156  13.566925  3.407175   15.366090
# 3                       716546491   9.724086  2.327935    9.168142
# 4                       716546491   8.757063  1.978925   11.197974
#
#                 ... Chỉ tiêu hiệu quả hoạt động                         \
#      EPS (VND)  ...        Fixed Asset Turnover Days Sales Outstanding
# 0  2448.177637  ...                    5.472447              12.718345
# 1  2292.912389  ...                    5.360159              12.461936
# 2  3170.253615  ...                    5.305980              11.197154
# 3  2525.996437  ...                    5.374126              10.234727
# 4  2265.555551  ...                    5.391219               8.944839
#
#                                                                    \
#   Days Inventory Outstanding Days Payable Outstanding  Cash Cycle
# 0                  55.295826                42.181951  110.196122
# 1                  56.837154                42.090181  111.389270
# 2                  56.800416                42.590887  110.588457
# 3                  56.939927                37.547090  104.721744
# 4                  55.990614                33.660873   98.596326
#
#                      Chỉ tiêu cơ cấu nguồn vốn              \
#   Inventory Turnover (ST+LT borrowings)/Equity Debt/Equity
# 0           6.600860                  0.236148    0.399622
# 1           6.421856                  0.261178    0.431420
# 2           6.426009                  0.338328    0.537510
# 3           6.410265                  0.348338    0.566766
# 4           6.518950                  0.318032    0.481450
#
#
#   Fixed Asset-To-Equity Owners' Equity/Charter Capital
# 0              0.181616                       4.102293
# 1              0.195022                       3.856566
# 2              0.210512                       3.620915
# 3              0.217640                       3.309677
# 4              0.204077                       3.499723
#
# [5 rows x 37 columns]

# %%
df_fin1 = df_fin[df_fin['Meta']['yearReport'].isin([2023,2024])]

# %%
df_fin1.columns = df_fin1.columns.droplevel(0)
df_fin1.head()
# Out:
#   ticker  yearReport  lengthReport       P/B  Market Capital (Bn. VND)  \
# 0    MCH        2024             2  4.955222           144839582045940
# 1    MCH        2024             1  5.077884           139499893790988
# 2    MCH        2023             4  3.725532            96222014662536
# 3    MCH        2023             3  2.755326            64759322217107
# 4    MCH        2023             2  2.197743            54762782121166
#
#    Outstanding Share (Mil. Shares)        P/E       P/S  P/Cash Flow  \
# 0                        717507156  19.332802  4.877609    22.156469
# 1                        717507156  18.951058  4.846342    21.443997
# 2                        717507156  13.566925  3.407175    15.366090
# 3                        716546491   9.724086  2.327935     9.168142
# 4                        716546491   8.757063  1.978925    11.197974
#
#      EPS (VND)  ...  Fixed Asset Turnover  Days Sales Outstanding  \
# 0  2448.177637  ...              5.472447               12.718345
# 1  2292.912389  ...              5.360159               12.461936
# 2  3170.253615  ...              5.305980               11.197154
# 3  2525.996437  ...              5.374126               10.234727
# 4  2265.555551  ...              5.391219                8.944839
#
#    Days Inventory Outstanding  Days Payable Outstanding  Cash Cycle  \
# 0                   55.295826                 42.181951  110.196122
# 1                   56.837154                 42.090181  111.389270
# 2                   56.800416                 42.590887  110.588457
# 3                   56.939927                 37.547090  104.721744
# 4                   55.990614                 33.660873   98.596326
#
#    Inventory Turnover  (ST+LT borrowings)/Equity  Debt/Equity  \
# 0            6.600860                   0.236148     0.399622
# 1            6.421856                   0.261178     0.431420
# 2            6.426009                   0.338328     0.537510
# 3            6.410265                   0.348338     0.566766
# 4            6.518950                   0.318032     0.481450
#
#    Fixed Asset-To-Equity  Owners' Equity/Charter Capital
# 0               0.181616                        4.102293
# 1               0.195022                        3.856566
# 2               0.210512                        3.620915
# 3               0.217640                        3.309677
# 4               0.204077                        3.499723
#
# [5 rows x 37 columns]

# %% [markdown]
# Earnings
# Generally, consistent growth is a good sign the business is healthy, although accounting practices can reduce reported earnings.
#
# Earnings per share
# Calculated by dividing net income by the total number of outstanding shares, it offers a window to the profitability of the company. Some prefer using a weighted ratio of net income minus total dividends for a more accurate picture before investing.
#
# Price to earnings ratio
# Typically calculated after yearly financials are made available, price to earnings is the market value price per share divided by earnings per share.
#
# Price to earnings growth ratio
# For further analysis, the price to earnings ratio can be divided by the growth rate of its earnings for a specified period of time.
#
# Book value
# Essentially, this is the accounting value of the company on the balance sheet and can be useful when compared to the company’s market value to determine if the stock is over- or undervalued.
#
# Free cash flow
# This the cash left over after a company pays its operating expenses plus capital expenditures and reflects how efficient a company is with cash and the potential to pay dividends or perhaps buy back stock.
#
# Return on equity
# This is a profitability measure calculated by dividing net income by the shareholder’s equity. In essence, how good is the company at using the stockholder’s money to generate net income?
#
# Return on assets
# Similarly, this calculation indicates how efficient a company is at using its assets to generate a profit. The formula is net income divided by average total assets.
#
# Net margins
# By dividing net income by sales, you can determine how efficiently a company is creating profit. The nature of certain businesses requires a significantly greater volume of revenue to show profit and consequently can be expected to have relatively low net margins as compared to other types of businesses.

# %%
df_fin1.columns
# Out:
# Index(['ticker', 'yearReport', 'lengthReport', 'P/B',
#        'Market Capital (Bn. VND)', 'Outstanding Share (Mil. Shares)', 'P/E',
#        'P/S', 'P/Cash Flow', 'EPS (VND)', 'BVPS (VND)', 'EV/EBITDA',
#        'Gross Profit Margin (%)', 'Net Profit Margin (%)', 'ROE (%)',
#        'ROIC (%)', 'ROA (%)', 'Biên EBIT (%)', 'EBITDA (Bn. VND)',
#        'EBIT (Bn. VND)', 'Dividend yield (%)', 'Current Ratio', 'Cash Ratio',
#        'Quick Ratio', 'Interest Coverage', 'Financial Leverage',
#        'Asset Turnover', 'Fixed Asset Turnover', 'Days Sales Outstanding',
#        'Days Inventory Outstanding', 'Days Payable Outstanding', 'Cash Cycle',
#        'Inventory Turnover', '(ST+LT borrowings)/Equity', 'Debt/Equity',
#        'Fixed Asset-To-Equity', 'Owners' Equity/Charter Capital'],
#       dtype='object')

# %%
criteria = ['ticker', 'yearReport', 'lengthReport','P/B', 'Gross Profit Margin (%)', 'Net Profit Margin (%)', 'ROE (%)', 'P/E', 'ROA (%)', 'EPS (VND)', 'Debt/Equity']

# %%
def DataCollection(company):
    stock = Vnstock().stock(symbol=company, source='VCI')
    df_fin = stock.finance.ratio(period='quarter')
    df1 = df_fin[df_fin['Meta']['yearReport'].isin([2023,2024])]
    df1.columns = df1.columns.droplevel(0)
    df_fin = df1[criteria]
    print('error')
    return df_fin

# %%
com_list = df_cat['symbol'].to_list()

# %%
print(com_list)
# Out:
# ['CCC', 'HIO', 'TSA', 'CST', 'SGI', 'TOS', 'DSD', 'HLO', 'AAH', 'D17', 'AAV', 'ATG', 'ACL', 'BGE', 'BCR', 'ADC', 'AMV', 'BVN', 'ALV', 'ATS', 'BAL', 'VLB', 'AMC', 'BCB', 'CSC', 'ABS', 'ABW', 'BMN', 'BNW', 'BOT', 'AMD', 'BRS', 'ACB', 'BST', 'CVN', 'BTW', 'ACC', 'AME', 'BVG', 'BCC', 'BVH', 'C21', 'CMW', 'DND', 'CBS', 'GEE', 'CDC', 'CMK', 'BDB', 'CMF', 'ACE', 'TS3', 'CEN', 'CMX', 'BSC', 'EID', 'DWS', 'CE1', 'C4G', 'BHI', 'ACG', 'CJC', 'CK8', 'CKD', 'D11', 'DNE', 'CKV', 'CLW', 'BDG', 'TIN', 'CAT', 'CNG', 'BSR', 'CLL', 'EIB', 'CMD', 'CIA', 'PRT', 'CMS', 'GAS', 'SGP', 'CPA', 'ACM', 'BEL', 'CTS', 'CT3', 'HC1', 'IST', 'D2D', 'NBT', 'ICT', 'FLC', 'DAH', 'XMC', 'APC', 'BTP', 'DPH', 'DRG', 'CCT', 'BGW', 'DRI', 'C12', 'ADS', 'CIP', 'DP1', 'CBI', 'APF', 'CYC', 'DWC', 'HBS', 'DBT', 'DC2', 'HDS', 'DDV', 'BHK', 'DTP', 'APH', 'BTS', 'CPI', 'API', 'DHA', 'DHM', 'ADP', 'APL', 'DC1', 'DID', 'HAI', 'DLG', 'DLR', 'HII', 'BCM', 'NSS', 'DNH', 'DNL', 'AGF', 'BLT', 'KCB', 'DBD', 'CKA', 'DNN', 'LCM', 'CAG', 'DOP', 'DPC', 'CSV', 'HLC', 'CDN', 'CCI', 'CCL', 'LTG', 'CTA', 'CCM', 'AGR', 'DTA', 'DTE', 'DSG', 'DVW', 'DXL', 'DXV', 'EBS', 'BLN', 'A32', 'EMS', 'ASG', 'EVF', 'LEC', 'THM', 'EIC', 'TVH', 'CTC', 'AGG', 'CDH', 'HDA', 'CTD', 'DFF', 'DGC', 'PNT', 'HPT', 'CDG', 'DHG', 'CTF', 'HSV', 'DNP', 'CTG', 'FBA', 'DAC', 'DCR', 'FCM', 'FDC', 'ASM', 'EVG', 'FIC', 'BVL', 'DHP', 'ASP', 'BII', 'ART', 'DSC', 'VSM', 'ILB', 'FMC', 'ATB', 'CMT', 'DP3', 'IDP', 'FPT', 'CTN', 'TNH', 'AG1', 'FTS', 'HHG', 'COM', 'CTP', 'FRC', 'CMV', 'FTI', 'BVS', 'HNM', 'HID', 'ITA', 'M10', 'GSM', 'DTT', 'KBC', 'HMH', 'FHS', 'VTZ', 'GAB', 'ROS', 'GDT', 'KDM', 'GER', 'NTP', 'DAN', 'STK', 'GHC', 'CEO', 'MGG', 'FGL', 'GLW', 'GIL', 'GLC', 'GEG', 'GLT', 'GMD', 'TVA', 'GMX', 'TTE', 'BKC', 'BLF', 'GGG', 'DIH', 'KSB', 'CTT', 'DMN', 'DTB', 'HU6', 'H11', 'CDP', 'TW3', 'HDP', 'HAG', 'HAH', 'BWS', 'HPX', 'HNR', 'HLB', 'GMA', 'HTV', 'HHV', 'KTT', 'HAN', 'AVF', 'NBE', 'NRC', 'L12', 'HNP', 'HAP', 'TTS', 'HTM', 'PAS', 'PCT', 'PDB', 'HAX', 'BMF', 'DLD', 'PID', 'PJC', 'HBH', 'PJS', 'PLA', 'PLO', 'HCC', 'FID', 'PMC', 'HMR', 'PMW', 'HCI', 'HTE', 'HDC', 'LAF', 'FIR', 'KTW', 'POT', 'PPI', 'LSG', 'CH5', 'PSE', 'PTO', 'HDW', 'QNC', 'HFC', 'NBW', 'DXG', 'HFX', 'OIL', 'HGT', 'HHC', 'LKW', 'PVP', 'PVV', 'PXS', 'PQN', 'SAL', 'MA1', 'DS3', 'HKT', 'NHP', 'QNP', 'QPH', 'HLD', 'CHP', 'MEL', 'RCL', 'HLS', 'BMS', 'DBC', 'DPM', 'XDH', 'LPT', 'CTW', 'L43', 'DPP', 'LGL', 'CI5', 'FCS', 'JOS', 'AAA', 'AAM', 'HNA', 'NLG', 'HOM', 'NT2', 'QHD', 'GTT', 'SAP', 'SKH', 'CHS', 'HPW', 'MLS', 'MWG', 'FTM', 'HRB', 'CNN', 'HSP', 'E29', 'HTG', 'HOT', 'MST', 'CAR', 'HPG', 'BXH', 'HU4', 'ECI', 'HWS', 'DBM', 'HNI', 'HPH', 'TCH', 'HUG', 'GH3', 'SC5', 'HNB', 'SCG', 'HCM', 'LGC', 'B82', 'PGN', 'ICF', 'ICG', 'DMS', 'ICI', 'IDI', 'NAG', 'IDC', 'DC4', 'HAV', 'SD4', 'SD5', 'MBN', 'VPD', 'TUG', 'SDC', 'CVT', 'DHN', 'DNC', 'HQC', 'HPB', 'IHK', 'CX8', 'HRC', 'SCD', 'HEP', 'HPI', 'IJC', 'VET', 'IME', 'DCL', 'IMP', 'IN4', 'IBD', 'DRC', 'HTC', 'SCJ', 'DRL', 'ELC', 'DDG', 'HTN', 'SCR', 'TOW', 'RDP', 'EMG', 'DST', 'ALT', 'ING', 'C69', 'HTL', 'NHT', 'SDJ', 'HTT', 'HU1', 'SDV', 'HSI', 'IPA', 'EPC', 'BHN', 'DDN', 'SDY', 'SPV', 'AAS', 'BCV', 'DCM', 'HMC', 'DNW', 'HSG', 'BTH', 'CID', 'CMN', 'SFI', 'SGB', 'BNA', 'BSG', 'DCG', 'SGR', 'MTV', 'FCN', 'AGP', 'HFB', 'CII', 'XMD', 'HCB', 'HD6', 'HUT', 'HVA', 'SZC', 'NHA', 'KDC', 'L40', 'CKG', 'KHG', 'KHW', 'VW3', 'LCS', 'VBG', 'KHL', 'HDG', 'HVX', 'MH3', 'MTH', 'ICC', 'NLS', 'NTT', 'DP2', 'GIC', 'DHB', 'SMN', 'KGM', 'DDM', 'NO1', 'BDT', 'AVC', 'DTC', 'HPM', 'HVT', 'INN', 'ISG', 'ITC', 'JVC', 'CPC', 'FRM', 'KLB', 'KLF', 'IVS', 'MPC', 'NAF', 'NVT', 'OCH', 'KHD', 'PEQ', 'PLX', 'SMT', 'KST', 'NGC', 'PFL', 'PLP', 'HLT', 'LMC', 'PIC', 'HSM', 'PIS', 'SPD', 'L14', 'CTB', 'NJC', 'DGW', 'L18', 'PPE', 'L44', 'L61', 'L62', 'DIG', 'GCB', 'LBC', 'PXT', 'LCC', 'REE', 'PND', 'S99', 'SBD', 'LGM', 'LHC', 'LHG', 'PPC', 'SBM', 'SCS', 'LIX', 'SDN', 'SSB', 'LM3', 'LM7', 'SRC', 'SSC', 'LSS', 'LTC', 'DTI', 'LUT', 'SRT', 'SDU', 'SJF', 'SHA', 'LO5', 'P ...

# %%
df = DataCollection("MCH")
prog = 0
for company in com_list:
    print("Number of stock pull: ",prog)
    prog += 1
    try:
        df1 = DataCollection(company)
        df = pd.concat([df, df1], ignore_index=True)
    except:
        print('error')
# Out:
# 2024-08-03 02:20:01,398 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# 2024-08-03 02:20:04,524 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  0
# /tmp/ipykernel_161/3452690180.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df1], ignore_index=True)
# 2024-08-03 02:20:06,524 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1
# 2024-08-03 02:20:08,649 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  2
# 2024-08-03 02:20:10,718 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  3
# 2024-08-03 02:20:13,620 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  4
# 2024-08-03 02:20:15,957 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  5
# 2024-08-03 02:20:18,460 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  6
# 2024-08-03 02:20:20,724 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  7
# 2024-08-03 02:20:21,433 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  8
# 2024-08-03 02:20:23,608 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  9
# 2024-08-03 02:20:24,329 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:
- vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1555
# 2024-08-03 03:23:50,061 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1556
# 2024-08-03 03:23:53,219 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1557
# 2024-08-03 03:23:55,716 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1558
# 2024-08-03 03:23:58,753 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1559
# 2024-08-03 03:24:01,277 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1560
# 2024-08-03 03:24:04,296 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1561
# 2024-08-03 03:24:06,836 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1562
# 2024-08-03 03:24:10,723 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1563
# 2024-08-03 03:24:13,694 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1564
# 2024-08-03 03:24:16,433 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1565
# 2024-08-03 03:24:19,402 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1566
# 2024-08-03 03:24:21,970 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1567
# 2024-08-03 03:24:24,453 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1568
# 2024-08-03 03:24:27,061 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1569
# 2024-08-03 03:24:29,834 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1570
# 2024-08-03 03:24:32,698 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1571
# 2024-08-03 03:24:35,439 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1572
# 2024-08-03 03:24:38,404 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1573
# 2024-08-03 03:24:41,065 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1574
# 2024-08-03 03:24:43,826 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1575
# 2024-08-03 03:24:44,611 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1576
# 2024-08-03 03:24:47,093 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1577
# 2024-08-03 03:24:49,690 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1578
# /tmp/ipykernel_161/3452690180.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df1], ignore_index=True)
# 2024-08-03 03:24:51,733 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1579
# 2024-08-03 03:24:54,246 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1580
# 2024-08-03 03:24:57,698 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1581
# 2024-08-03 03:24:58,321 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1582
# /tmp/ipykernel_161/3452690180.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df1], ignore_index=True)
# 2024-08-03 03:25:00,254 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1583
# 2024-08-03 03:25:00,816 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1584
# 2024-08-03 03:25:03,356 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1585
# 2024-08-03 03:25:05,419 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1586
# 2024-08-03 03:25:08,156 - vnstock3.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# error
# Number of stock pull:  1587
# error

# %%
df.head()
# Out:
#   ticker  yearReport  lengthReport       P/B  Gross Profit Margin (%)  \
# 0    MCH        2024             2  4.955222                 0.462449
# 1    MCH        2024             1  5.077884                 0.467420
# 2    MCH        2023             4  3.725532                 0.472956
# 3    MCH        2023             3  2.755326                 0.465835
# 4    MCH        2023             2  2.197743                 0.459871
#
#    Net Profit Margin (%)   ROE (%)        P/E   ROA (%)    EPS (VND)  \
# 0               0.237777  0.282548  19.332802  0.186741  2448.177637
# 1               0.250011  0.289290  18.951058  0.188179  2292.912389
# 2               0.267816  0.297086  13.566925  0.191312  3170.253615
# 3               0.250228  0.284498   9.724086  0.185299  2525.996437
# 4               0.250625  0.277298   8.757063  0.182880  2265.555551
#
#    Debt/Equity
# 0     0.399622
# 1     0.431420
# 2     0.537510
# 3     0.566766
# 4     0.481450

# %%
df.shape
# Out:
# (6719, 11)

# %%
df_final = df.dropna()
df.shape
# Out:
# (6719, 11)

# %%
df_cat.head()
# Out:
#   symbol                                         organ_name  \
# 0    CCC                       Công ty Cổ Phần Xây Dựng CDC
# 1    HIO                       Công ty Cổ Phần Helio Energy
# 2    TSA       Công ty Cổ Phần Đầu Tư Và Xây Lắp Trường Sơn
# 3    CST                 Công ty Cổ phần Than Cao Sơn - TKV
# 4    SGI  Công ty Cổ phần Đầu tư phát triển Sài Gòn 3 Group
#
#                                        en_organ_name  \
# 0               CDC Construction Joint Stock Company
# 1                   Helio Energy Joint Stock Company
# 2  Truong Son Investment And Construction Joint S...
# 3                   Cao Son Coal Joint Stock Company
# 4  Sai Gon 3 Group Investment Development Joint S...
#
#                    icb_name3              en_icb_name3  \
# 0       Xây dựng và Vật liệu  Construction & Materials
# 1  Sản xuất & Phân phối Điện               Electricity
# 2       Xây dựng và Vật liệu  Construction & Materials
# 3                Khai khoáng                    Mining
# 4               Hàng cá nhân            Personal Goods
#
#                        icb_name2                en_icb_name2  \
# 0           Xây dựng và Vật liệu    Construction & Materials
# 1  Điện, nước & xăng dầu khí đốt                   Utilities
# 2           Xây dựng và Vật liệu    Construction & Materials
# 3              Tài nguyên Cơ bản             Basic Resources
# 4        Hàng cá nhân & Gia dụng  Personal & Household Goods
#
#                    icb_name4              en_icb_name4 com_type_code  \
# 0                   Xây dựng        Heavy Construction            CT
# 1  Sản xuất & Phân phối Điện  Conventional Electricity            CT
# 2                   Xây dựng        Heavy Construction            CT
# 3             Khai thác Than                      Coal            CT
# 4               Hàng May mặc    Clothing & Accessories            CT
#
#   icb_code1 icb_code2 icb_code3 icb_code4
# 0      2000      2300      2350      2357
# 1      7000      7500      7530      7535
# 2      2000      2300      2350      2357
# 3      1000      1700      1770      1771
# 4      3000      3700      3760      3763

# %%
df_final = pd.merge(df_final, df_cat[['symbol','organ_name','en_organ_name','icb_name3','en_icb_name3','icb_code3']], left_on='ticker', right_on='symbol', how='inner')
df_final.head()
# Out:
#   ticker  yearReport  lengthReport       P/B  Gross Profit Margin (%)  \
# 0    MCH        2024             2  4.955222                 0.462449
# 1    MCH        2024             1  5.077884                 0.467420
# 2    MCH        2023             4  3.725532                 0.472956
# 3    MCH        2023             3  2.755326                 0.465835
# 4    MCH        2023             2  2.197743                 0.459871
#
#    Net Profit Margin (%)   ROE (%)        P/E   ROA (%)    EPS (VND)  \
# 0               0.237777  0.282548  19.332802  0.186741  2448.177637
# 1               0.250011  0.289290  18.951058  0.188179  2292.912389
# 2               0.267816  0.297086  13.566925  0.191312  3170.253615
# 3               0.250228  0.284498   9.724086  0.185299  2525.996437
# 4               0.250625  0.277298   8.757063  0.182880  2265.555551
#
#    Debt/Equity symbol                            organ_name  \
# 0     0.399622    MCH  Công ty Cổ phần Hàng Tiêu Dùng MaSan
# 1     0.431420    MCH  Công ty Cổ phần Hàng Tiêu Dùng MaSan
# 2     0.537510    MCH  Công ty Cổ phần Hàng Tiêu Dùng MaSan
# 3     0.566766    MCH  Công ty Cổ phần Hàng Tiêu Dùng MaSan
# 4     0.481450    MCH  Công ty Cổ phần Hàng Tiêu Dùng MaSan
#
#                 en_organ_name           icb_name3    en_icb_name3 icb_code3
# 0  Masan Consumer Corporation  Sản xuất thực phẩm  Food Producers      3570
# 1  Masan Consumer Corporation  Sản xuất thực phẩm  Food Producers      3570
# 2  Masan Consumer Corporation  Sản xuất thực phẩm  Food Producers      3570
# 3  Masan Consumer Corporation  Sản xuất thực phẩm  Food Producers      3570
# 4  Masan Consumer Corporation  Sản xuất thực phẩm  Food Producers      3570

# %%
df_final.shape
# Out:
# (6485, 17)

# %%
df_final.to_csv("stock_data_raw.csv", sep='\t', encoding='utf-8', index=False, header=True)
